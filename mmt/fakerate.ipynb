# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, TFile, gPad, TPad, TF1, gStyle, TGraphErrors
import sys
from array import array                                                                                                                                                            
import numpy as np
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM0; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult1 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Info in <TBinomialEfficiencyFitter::result>:  chi2 1.781613 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM1; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult2 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 6.263876 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM10; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult3 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 2.200227 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM11; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult4 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 2.371146 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM0; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult5 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 0.517365 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM1; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult6 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 1.115489 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM10; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult7 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 3.444650 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM11; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult8 = h.Fit(f, "S")
#steps = 500
#x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
#y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                             
#ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
#zeros = np.zeros(graph.GetN())                                                                                                                                             
#interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
#interval.SetFillColor(2)                                                                                                                                                   
#interval.SetFillStyle(3002)                                                                                                                                                
#interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 4.006973 ndf 0

# %%
f = TFile("FRMMT.root", "Recreate")
fitResult1.Write("EBDM0")
fitResult2.Write("EBDM1")
fitResult3.Write("EBDM10")
fitResult4.Write("EBDM11")
fitResult5.Write("EEDM0")
fitResult6.Write("EEDM1")
fitResult7.Write("EEDM10")
fitResult8.Write("EEDM11")
f.Close()
