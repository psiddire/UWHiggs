# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, TFile, gPad, TPad, TF1, gStyle
import sys
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEBDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM0; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 17.211030 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEBDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM1; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 29.978894 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEBDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM10; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 14.726350 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEBDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM11; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 27.171284 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEEDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM0; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 9.229803 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEEDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM1; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 13.041782 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEEDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM10; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 14.685921 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEEDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM11; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 4.205236 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
legend = TLegend(0.5,0.6,0.88,0.8)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEta.root')
h = fi.Get('fakerate')
hdy = fi.Get('dyfakerate')
hdy.SetLineColor(2)
legend.AddEntry(h,"Data","l")
legend.AddEntry(hdy,"Z+Jets","l")
h.Draw()
hdy.Draw("SAME")
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate; Tau Eta; Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
legend.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TEfficiency::GetEfficiencyErrorLow>: frequentist confidence intervals for weights are only supported by the normal approximation
# Info in <TEfficiency::GetEfficiencyErrorLow>: setting statistic option to kFNormal
