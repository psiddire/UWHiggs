# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend
import sys                                                                                                                                                                                                                                                  
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('GluGlu.root')
f2 = TFile('GluGlu_LFV_HToETau_M125_13TeV_powheg_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h1 = f1.Get('TightOS/e_t_CollinearMass')
h2 = f2.Get('TightOS/e_t_CollinearMass')
h2.SetLineColor(3)
h1.Draw()
h2.Draw("SAME")
canvas.Draw()
print h1.Integral()
print h2.Integral()
# Out:
# 797.502326395
# 793.086528277
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('VBF.root')
f2 = TFile('VBF_LFV_HToETau_M125_13TeV_powheg_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h1 = f1.Get('TightOS/e_t_CollinearMass')
h2 = f2.Get('TightOS/e_t_CollinearMass')
h2.SetLineColor(3)
h1.Draw()
h2.Draw("SAME")
canvas.Draw()
print h1.Integral()
print h2.Integral()
# Out:
# 62.3722373055
# 59.8569308173
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('GluGlu.root')
f2 = TFile('GluGlu_LFV_HToETau_M125_13TeV_powheg_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h1 = f1.Get('TightOS2Jet/e_t_CollinearMass')
h2 = f2.Get('TightOS2Jet/e_t_CollinearMass')
h2.SetLineColor(3)
h1.Draw()
h2.Draw("SAME")
canvas.Draw()
print h1.Integral()
print h2.Integral()
# Out:
# 48.2462013895
# 47.4364662464
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('VBF.root')
f2 = TFile('VBF_LFV_HToETau_M125_13TeV_powheg_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h1 = f1.Get('TightOS2JetVBF/e_t_CollinearMass')
h2 = f2.Get('TightOS2JetVBF/e_t_CollinearMass')
h2.SetLineColor(3)
h1.Draw()
h2.Draw("SAME")
canvas.Draw()
print h1.Integral()
print h2.Integral()
# Out:
# 14.6783851508
# 13.578292664
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
