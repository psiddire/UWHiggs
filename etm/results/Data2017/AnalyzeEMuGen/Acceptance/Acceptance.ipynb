# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend
import sys     
import math
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)

# %%
def positivize(histogram):
    output = histogram.Clone()
    for i in range(output.GetSize()):
        if output.GetArray()[i] < 0:
            output.AddAt(0, i)
    return output

# %%
def round_up(n, decimals=0):
    multiplier = 10 ** decimals
    return math.ceil(n * multiplier) / multiplier

# %%
f = TFile('Diboson.root')

h = f.Get('TightOS/e_m_CollinearMass')
h1 = f.Get('TightOS0Jet/e_m_CollinearMass')
h2 = f.Get('TightOS1Jet/e_m_CollinearMass')
h3 = f.Get('TightOS2Jet/e_m_CollinearMass')
h4 = f.Get('TightOS2JetVBF/e_m_CollinearMass')

print round_up(h.Integral(), 3)
print round_up(h1.Integral(), 3)
print round_up(h2.Integral(), 3)
print round_up(h3.Integral(), 3)
print round_up(h4.Integral(), 3)
# Out:
# 49952.212
# 33442.693
# 12811.146
# 3404.268
# 294.107

# %%
canvas = TCanvas("", "", 800, 800)
f = TFile('Eta.root')
h = f.Get('0Jet')
h.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name:
