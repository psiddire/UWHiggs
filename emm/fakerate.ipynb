# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, TFile, gPad, TPad, TF1, gStyle
import sys
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frElePt.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate; Electron pT (GeV); Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.5)
gPad.Update()
f = TF1("Complex law","([0]/(1+ TMath::Exp(-[1]*(x-[2]))))", 0, 200)#([0]/(1+ TMath::Exp(-[1]*(x-[2])))) #[0]*TMath::Erf((x-[1])/[2])
f.SetParameters(1, 1, 60)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 9.486686 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEleEta.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate; Electron Eta; Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", -2.1, 2.1)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 39.315978 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frElePtEB.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate EB; Electron pT (GeV); Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.5)
gPad.Update()
f = TF1("Complex law","([0]/(1+ TMath::Exp(-[1]*(x-[2]))))", 0, 200)#[0]+sqrt(x)*[1]
f.SetParameters(1, 1, 60)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 7.678817 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frElePtEE.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate EE; Electron pT (GeV); Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.5)
gPad.Update()
f = TF1("Complex law","([0]/(1+ TMath::Exp(-[1]*(x-[2]))))", 0, 200)
f.SetParameters(1, 1, 60)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 3.335768 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frElePtEB.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate EB; Electron pT (GeV); Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.5)
gPad.Update()
f = TF1("Complex law","([0]/(1+ TMath::Exp(-[1]*(x-[2]))))", 0, 200)#[0]+sqrt(x)*[1]
f.SetParameters(1, 1, 60)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 17.277432 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frElePtEE.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate EE; Electron pT (GeV); Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.5)
gPad.Update()
f = TF1("Complex law","([0]/(1+ TMath::Exp(-[1]*(x-[2]))))", 0, 200)
f.SetParameters(1, 1, 60)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 5.540639 ndf 0
