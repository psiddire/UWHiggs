# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend
import sys                                                                                                                                                                                                                                                  
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/embed.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/mGen')
h2 = f1.Get('MuonLooseOS/mGen')
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/embed.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/mMotherGen')
h2 = f1.Get('MuonLooseOS/mMotherGen')
print h2.Integral()
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()
# Out:
# 1008.92077637
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/embed.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/tGen')
h2 = f1.Get('MuonLooseOS/tGen')
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/embed.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/tMotherGen')
h2 = f1.Get('MuonLooseOS/tMotherGen')
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/Drell.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/mGen')
h2 = f1.Get('MuonLooseOS/mGen')
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/Drell.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/mMotherGen')
h2 = f1.Get('MuonLooseOS/mMotherGen')
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/Drell.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/tGen')
h2 = f1.Get('MuonLooseOS/tGen')
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.52,0.7,0.8,0.8)
f1 = TFile('../results/DataApril3/AnalyzeMuTauGen/Drell.root')                                                                                                                                                                                                                              
h1 = f1.Get('TightOS/tMotherGen')
h2 = f1.Get('MuonLooseOS/tMotherGen')
h2.SetLineColor(2)
h1.Draw()
h2.Draw('SAME')
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
