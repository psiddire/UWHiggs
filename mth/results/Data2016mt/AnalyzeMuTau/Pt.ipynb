# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend, gStyle
import sys                                                                                                                                                                                                                                                  
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)
gStyle.SetOptStat(0)

# %%
def positivize(histogram):
    output = histogram.Clone()
    for i in range(output.GetSize()):
        if output.GetArray()[i] < 0:
            output.AddAt(0, i)
    return output

# %%
canvas = TCanvas("", "", 800, 800)
leg = TLegend(0.52,0.7,0.9,0.9)
f = TFile('../../../../mte/results/Data2016/AnalyzeMuE/GluGlu_LFV_HToMuTau_M125_13TeV_powheg_pythia8_v3-PUMoriond17_94X_mcRun2_asymptotic_v3-v2.root')
h1 = f.Get('TightOS0Jet/m_e_Mass')
h2 = f.Get('TightOS0Jet/m_e_CollMass')
h1.GetXaxis().SetTitle("Mass (GeV)")
h1.GetYaxis().SetTitle("Events per bin")
h1.SetTitle("")
h2.SetLineColor(2)
h1.Draw("HIST E")
h2.Draw("HIST E SAME")
leg.AddEntry(h1, "Visible Mass", "l")
leg.AddEntry(h2, "Collinear Mass", "l")
leg.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name:
