# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, gStyle, TFile, TIter, gSystem
import sys
gROOT.SetStyle("Default")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.10/09

# %%
canvas = TCanvas("canvas","canvas",800,800)
file = '../../../FinalStateAnalysis/TagAndProbe/data/pileupTTToSemiLeptonic.root'
f = TFile("../../../FinalStateAnalysis/TagAndProbe/data/pileupTTToSemiLeptonicnew.root","RECREATE")
MuTaufile = TFile(file)
lfv_histo = MuTaufile.Get('pileup')
hlist = lfv_histo.GetListOfKeys()
iter = TIter(hlist)
for i in iter:
    if i.GetName()=='pileup':
        histo = MuTaufile.Get('pileup/'+i.GetName())
        print histo.Integral()
        histo.Draw("hist")
canvas.Draw()
histo.SetDirectory(f)
f.Write()
# Out:
# 699719120.0
# 1123
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
