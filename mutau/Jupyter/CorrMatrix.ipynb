# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, gStyle, TFile, TIter, gSystem, TTree
import sys
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.10/09

# %%
canvas = TCanvas("canvas","canvas",800,800)
file = 'TMVA.root'
MuTaufile = TFile(file)
histo = MuTaufile.Get('dataset/CorrelationMatrixS')
histo.GetYaxis().SetLabelSize(0.015)
histo.GetXaxis().SetLabelSize(0.04)
histo.Draw("colztext")
canvas.Draw()
canvas.SaveAs('CorrMatrixS.png')
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file CorrMatrixS.png has been created
