# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, gStyle, TFile, TIter, gSystem
import sys
gROOT.SetStyle("Default")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.10/09

# %%
canvas = TCanvas("canvas","canvas",800,800)
file = 'results/lpairs_data_Aug1/PileupAnalyzer/DY1JetsToLL_M-50_TuneCP5_13TeV-madgraphMLM-pythia8_v14-v1.root'
f = TFile("pileupDY1.root","RECREATE")
MuTaufile = TFile(file)
lfv_histo = MuTaufile.Get('pileup')
hlist = lfv_histo.GetListOfKeys()
iter = TIter(hlist)
for i in iter:
    if i.GetName()=='pileup':
        histo = MuTaufile.Get('pileup/'+i.GetName())
        print histo.Integral()
        histo.Draw("hist")
canvas.Draw()
histo.SetDirectory(f)
f.Write()
# Out:
# 18898850.0
# 1527
