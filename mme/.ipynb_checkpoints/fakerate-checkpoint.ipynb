# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, TFile, gPad, TPad, TF1, gStyle
import sys
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frElePt.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate; Electron pT (GeV); Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.5)
gPad.Update()
f = TF1("Complex law","tanh([0]+[1]*x)", 0, 200)
f.SetParameters(0, 0)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 43.976846 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frPt.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate; Electron pT (GeV); Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.5)
gPad.Update()
f = TF1("Complex law","tanh([0]+[1]*x)", 0, 200)
f.SetParameters(0, 0)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 32.583490 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEleEta.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Electron Fake Rate; Electron Eta; Fake Rate")
graph.SetMinimum(0.0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", -2.1, 2.1)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 39.315978 ndf 0
