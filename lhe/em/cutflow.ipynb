# %%
from ROOT import TFile, TIter, TCanvas, gROOT, gStyle
gROOT.SetStyle("Default")
gROOT.SetBatch(True)
gStyle.SetOptTitle(0)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
canvas = TCanvas("canvas","canvas",800,800)

f = "results/MCLHE2018/AnalyzeEMuCF/GluGlu_LFV_HToETau_M125_TuneCP5_PSweights_13TeV_powheg_pythia8_-102X_upgrade2018_realistic_v15-v1.root"

MuTaufile = TFile(f)
cutflowhisto = MuTaufile.Get('./CUT_FLOW')
cutflowhisto.Draw("hist")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
print "Overall Cut Efficiency: ", round(cutflowhisto.GetBinContent(13)/cutflowhisto.GetBinContent(1), 3)
# Out:
# Overall Cut Efficiency:  0.42

# %%
print "Filter Efficiency: ", round(cutflowhisto.GetBinContent(2)/cutflowhisto.GetBinContent(1), 3)
print "OppSign Efficiency: ", round(cutflowhisto.GetBinContent(3)/cutflowhisto.GetBinContent(2), 3)
print "Trigger Efficiency: ", round(cutflowhisto.GetBinContent(4)/cutflowhisto.GetBinContent(3), 3)
print "Kinematics Efficiency: ", round(cutflowhisto.GetBinContent(5)/cutflowhisto.GetBinContent(4), 3)
print "DeltaR Efficiency: ", round(cutflowhisto.GetBinContent(6)/cutflowhisto.GetBinContent(5), 3)
print "NJets Efficiency: ", round(cutflowhisto.GetBinContent(7)/cutflowhisto.GetBinContent(6), 3)
print "Vetoes Efficiency: ", round(cutflowhisto.GetBinContent(8)/cutflowhisto.GetBinContent(7), 3)
print "bjetVeto Efficiency: ", round(cutflowhisto.GetBinContent(9)/cutflowhisto.GetBinContent(8), 3)
print "Obj1 ID Efficiency: ", round(cutflowhisto.GetBinContent(10)/cutflowhisto.GetBinContent(9), 3)
print "Obj1 Iso Efficiency: ", round(cutflowhisto.GetBinContent(11)/cutflowhisto.GetBinContent(10), 3)
print "Obj2 ID Efficiency: ", round(cutflowhisto.GetBinContent(12)/cutflowhisto.GetBinContent(11), 3)
print "Obj2 Iso Efficiency: ", round(cutflowhisto.GetBinContent(13)/cutflowhisto.GetBinContent(12), 3)
# Out:
# Filter Efficiency:  1.0
# OppSign Efficiency:  0.936
# Trigger Efficiency:  0.721
# Kinematics Efficiency:  1.0
# DeltaR Efficiency:  1.0
# NJets Efficiency:  0.959
# Vetoes Efficiency:  0.992
# bjetVeto Efficiency:  0.985
# Obj1 ID Efficiency:  0.814
# Obj1 Iso Efficiency:  0.973
# Obj2 ID Efficiency:  0.983
# Obj2 Iso Efficiency:  0.854
