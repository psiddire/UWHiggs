# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend
import array
import sys
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
def positivize(histogram):
    output = histogram.Clone()
    for i in range(output.GetSize()):
        if output.GetArray()[i] < 0:
            output.AddAt(0, i)
    return output

# %%
import glob
files = glob.glob('**')
# Out:
# 'DY1JetsToLL_M-50_TuneCUETP8M1_13TeV-madgraphMLM-pythia8_v3-PUMoriond17_94X_mcRun2_asymptotic_v3-v1.root'

# %%
f = TFile('../MC.root')
h = f.Get('0jet/')
print h.Integral(), h1.Integral(), h2.Integral()
# Out:
# 778.753440589 778.753513284 778.753360376

# %%
canvas = TCanvas("", "", 800, 800)
h0 = positivize(h0)
binning = array.array('d', [-1.0, -0.5, 0.0, 0.5, 1.0])
h0 = h0.Rebin(len(binning)-1, 'LFVGG', binning)
print h0.Integral()
h0.Draw()
canvas.Draw()
# Out:
# 305.152973175
# Warning in <TCanvas::Constructor>: Deleting canvas with same name:
