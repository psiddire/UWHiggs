# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend
import sys                                                                                                                                                                                                                                                  
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('AQCD.root')  
h1 = f1.Get('QCD0JetCut')
h1.Draw()
canvas.Draw()
print h1.Integral()
# Out:
# 80.6322697401

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('VLQCD.root')  
h1 = f1.Get('QCD0JetCut')
h1.Scale(806.322697401/h1.Integral(), "width")
h1.Draw()
canvas.Draw()
print h1.Integral()
# Out:
# 80.6322695389
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('AQCD.root')  
h1 = f1.Get('QCD1JetCut')
h1.Draw()
canvas.Draw()
print h1.Integral()
# Out:
# 46.3342633247
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('VLQCD.root')  
h1 = f1.Get('QCD1JetCut')
h1.Scale(463.342633247/h1.Integral(), "width")
h1.Draw()
canvas.Draw()
print h1.Integral()
# Out:
# 46.3342632726
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('AQCD.root')  
h1 = f1.Get('QCD2JetCut')
h1.Draw()
canvas.Draw()
print h1.Integral()
# Out:
# 22.7301487923
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('VLQCD.root')  
h1 = f1.Get('QCD2JetCut')
h1.Scale(227.301487923/h1.Integral(), "width")
h1.Draw()
canvas.Draw()
print h1.Integral()
# Out:
# 22.7301487736
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f1 = TFile('AQCD.root')  
h1 = f1.Get('QCD2JetVBFCut')
h1.Draw()
canvas.Draw()
print h1.Integral()
# Out:
# 0.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
f1 = TFile('AQCD.root')  
h1 = f1.Get('QCD')
print h1.Integral()
h2 = f1.Get('QCD0Jet')
print h2.Integral()
h3 = f1.Get('QCD1Jet')
print h3.Integral()
h4 = f1.Get('QCD2Jet')
print h4.Integral()
h5 = f1.Get('QCD2JetVBF')
print h5.Integral()
h6 = f1.Get('QCD0JetCut')
print h6.Integral()
h7 = f1.Get('QCD1JetCut')
print h7.Integral()
h8 = f1.Get('QCD2JetCut')
print h8.Integral()
h9 = f1.Get('QCD2JetVBFCut')
print h9.Integral()
# Out:
# 1260.73956656
# 637.990314364
# 465.537204862
# 149.363916814
# 12.2519552708
# 80.6322697401
# 46.3342633247
# 22.7301487923
# 0.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
f1 = TFile('Fake.root')  
h1 = f1.Get('QCD')
print h1.Integral()
h2 = f1.Get('QCD0Jet')
print h2.Integral()
h3 = f1.Get('QCD1Jet')
print h3.Integral()
h4 = f1.Get('QCD2Jet')
print h4.Integral()
h5 = f1.Get('QCD2JetVBF')
print h5.Integral()
h6 = f1.Get('QCD0JetCut')
print h6.Integral()
h7 = f1.Get('QCD1JetCut')
print h7.Integral()
h8 = f1.Get('QCD2JetCut')
print h8.Integral()
h9 = f1.Get('QCD2JetVBFCut')
print h9.Integral()
# Out:
# 10812.3504753
# 6996.38345146
# 2726.92070961
# 974.150542259
# 132.17760849
# 595.251916409
# 424.636155605
# 155.693496108
# 14.0129942894
