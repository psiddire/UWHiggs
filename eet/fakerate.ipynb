# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, TFile, gPad, TPad, TF1, gStyle, TGraphErrors
import sys
import numpy as np
from array import array
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 0; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")                                                                                                                                                                                                                                              
canvas.Draw()
# Out:
# Info in <TBinomialEfficiencyFitter::result>:  chi2 5.395764 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 1; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 3.987167 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 10; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 0.147660 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEBDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 11; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 14.858352 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 0; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 4.633167 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 1; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 3.457606 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 10; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 0.024035 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2018/frEEDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 11; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                                                                                                               
y = np.array([fitResult.GetParams()[0] + fitResult.GetParams()[1]*x[i] for i in range(steps)])                                                                                                                                                                        
ey = np.array([fitResult.GetErrors()[0] + fitResult.GetErrors()[1]*x[i] for i in range(steps)])                                                                                                                                                                       
zeros = np.zeros(graph.GetN())                                                                                                                                                                                                                                        
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                                                                                                                       
interval.SetFillColor(2)                                                                                                                                                                                                                                              
interval.SetFillStyle(3002)                                                                                                                                                                                                                                           
interval.Draw("e3 same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 13.811677 ndf 0

# %%
f = TFile("FREET.root", "Recreate")
fitResult1.Write("EBDM0")
fitResult2.Write("EBDM1")
fitResult3.Write("EBDM10")
fitResult4.Write("EBDM11")
fitResult5.Write("EEDM0")
fitResult6.Write("EEDM1")
fitResult7.Write("EEDM10")
fitResult8.Write("EEDM11")
f.Close()
