# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, TFile, gPad, TPad, TF1, gStyle
import sys
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEBDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM0; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Info in <TBinomialEfficiencyFitter::result>:  chi2 5.911713 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEBDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM1; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 13.349163 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEBDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EB DM10; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 16.743813 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEEDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM0; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 22.871485 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEEDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM1; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 15.813849 ndf 0

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('frEEDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate EE DM10; Tau pT (GeV); Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
h.Fit(f)
f.DrawClone("Same")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 13.185022 ndf 0
