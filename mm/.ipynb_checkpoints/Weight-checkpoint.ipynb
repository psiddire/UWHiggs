# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, gStyle, TFile, TIter, gSystem
import sys
gROOT.SetStyle("Default")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.10/09

# %%
canvas = TCanvas("canvas","canvas",800,800)
file0 = TFile('pileup_2017.root')
h = file0.Get('pileup_WJetsToLNu-LO')
#h.Scale(1./h.Integral())

file1 = TFile('pileupW.root')
h1 = file1.Get('pileup')
#for i in range(10):
#    h1.SetBinContent(i,0)
#h1.Scale(1./h1.Integral())
#h2 = h.Clone("h2")
#h2.SetMinimum(0.0)
#h2.SetMaximum(2.0)
#h2.SetStats(0)
#h2.Divide(h1)
#h2.Draw("ep")
canvas.Draw()
#print "ratio: ", h.GetBinContent(54)/h1.GetBinContent(54)
# Out:
# ratio:  0.613985507404
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
