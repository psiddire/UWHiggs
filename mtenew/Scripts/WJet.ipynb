# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend
import sys                                                                                                                                                                                                                                                  
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('WJet.root')                                                                                                                                                                                                                              
h = f.Get('TightOS0JetCut/m_e_CollinearMass')
h.Scale(364.678/h.Integral())
h.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('WJet.root')                                                                                                                                                                                                                              
h = f.Get('TightOS1JetCut/m_e_CollinearMass')
h.Scale(235.574/h.Integral())
h.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('WJet.root')                                                                                                                                                                                                                              
h = f.Get('TightOS2JetCut/m_e_CollinearMass')
h.Scale(34.3671/h.Integral())
h.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('WJet.root')                                                                                                                                                                                                                              
h = f.Get('TightOS2JetVBFCut/m_e_CollinearMass')
h.Scale(2.56926/h.Integral())
h.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
